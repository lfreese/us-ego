# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import xarray as xr
import matplotlib.pyplot as plt
import numpy as np
import cartopy.crs as ccrs
import cartopy.feature as cfeat
import pandas as pd

import sys
sys.path.append('../')
import utils
import plotting

# %%
ds = xr.open_dataset('final_data/HEMCO_emis.nc4')

# %%
ds_seasonal = utils.season_mean(ds)

# %%
plotting.plot_percent_emissions_dif(ds_seasonal, 'MODEL','egrid',
                                    ['EmisNO_Anthro', 'EmisSO2_Anthro'],['JJA','DJF'], 
                                    levels = np.arange(-10,11,1), lat_lon = plotting.lat_lon, figsize = [10,5])
plt.suptitle('e-grid vs US-EGO', fontsize = 20);
#plt.savefig('./Figures/egrid_model_emis_dif.png', bbox_inches = 'tight', dpi = 150)
