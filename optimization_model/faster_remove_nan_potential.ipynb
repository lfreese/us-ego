# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import datetime
import pandas as pd

# %%
#import dataset
#choose one of the datasets below, or enter a new name
#data_path = 'inventory_power_plants_final.nc' 
#data_path = 'inventory_power_plants_no-nuclear.nc' 
#data_path = 'inventory_power_plants_egrid.nc'
data_path = '../annual_emissions/inventory_power_plants_no-nuclear_EIA_2030_renewables.nc'

ds = xr.open_dataset(data_path, chunks={"time": 1})

# %%
for v in ds.data_vars:
    ds[v] = ds[v].where(~np.isnan(ds[v]), 0.)

# %%
ds[v]
# Out:
# <xarray.DataArray 'SO2' (time: 8760, lat: 400, lon: 900)>
# dask.array<where, shape=(8760, 400, 900), dtype=float64, chunksize=(1, 400, 900), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) datetime64[ns] 2016-01-01 ... 2016-12-30T23:00:00
#   * lat      (lat) float64 20.05 20.15 20.25 20.35 ... 59.65 59.75 59.85 59.95
#   * lon      (lon) float64 -139.9 -139.8 -139.8 -139.7 ... -50.25 -50.15 -50.05
# Attributes:
#     units:      kg/s/m2
#     long_name:  US SO2 power plant emissions from my optimization model
